# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
research_in_rd = wb.data.DataFrame('SP.POP.SCIE.RD.P6', ['GBR', 'MLT', 'DEU', 'FRA', 'ROU', 'SVN', 'CZE'], time=range(2002,2018))
research_in_rd.to_csv(r'C:\Python\Ironhack\Project2 Database\research_in_rd.csv')
research_in_rd
# Out:
#               YR2002       YR2003       YR2004       YR2005       YR2006  \
# economy
# CZE      1460.555908  1543.977905  1591.851562  2356.080566  2550.567139
# DEU      3260.092041  3295.277100  3309.573486  3335.034912  3434.569336
# FRA      3117.211914  3199.748291  3334.166992  3313.258545  3423.748535
# GBR      3340.221680  3638.090332  3824.261963  4123.531738  4176.312500
# MLT       682.186401   688.521423  1082.377319  1183.730225  1282.215332
# ROU       928.281982   965.221313   985.128967  1071.937622   895.767517
# SVN      2335.871338  1899.025146  2024.899780  2633.114502  2924.946289
#
#               YR2007       YR2008       YR2009       YR2010       YR2011  \
# economy
# CZE      2691.549316  2857.022217  2742.075195  2773.959961  2903.661621
# DEU      3578.503418  3733.278076  3922.214600  4058.000244  4188.811523
# FRA      3585.805908  3659.884766  3747.284668  3873.012939  3942.388916
# ...

# %%
journal_articles = wb.data.DataFrame('IP.JRN.ARTC.SC',['GBR', 'MLT', 'DEU', 'FRA', 'ROU', 'SVN', 'CZE'], time=range(2002,2018))
journal_articles
journal_articles.to_csv(r'C:\Python\Ironhack\Project2 Database\journal_articles.csv')

# %%
rd_expenditure = wb.data.DataFrame('GB.XPD.RSDV.GD.ZS',['GBR', 'MLT', 'DEU', 'FRA', 'ROU', 'SVN', 'CZE'], time=range(2002,2018))
rd_expenditure
rd_expenditure.to_csv(r'C:\Python\Ironhack\Project2 Database\rd_expenditure.csv')
